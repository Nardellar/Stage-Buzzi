# %% [markdown]
# <a href="https://colab.research.google.com/github/Nardellar/Stage-Buzzi/blob/narde_dev/stage_ottobre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Nardellar/Stage-Buzzi.git
# Out:
# Cloning into 'Stage-Buzzi'...
# remote: Enumerating objects: 948, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (175/175), done.
# ^C

# %%
# %cd Stage-Buzzi/
# !git checkout narde_dev
# Out:
# /content/Stage-Buzzi
# Branch 'narde_dev' set up to track remote branch 'narde_dev' from 'origin'.
# Switched to a new branch 'narde_dev'

# %% [markdown]
# Per autenticarti con Hugging Face e superare la limitazione di velocità, aggiungi il tuo token di accesso come secret di Colab (nome: `HF_TOKEN`) e poi esegui la cella qui sotto:

# %%
from huggingface_hub import login
from google.colab import userdata

# Recupera il token dal secret di Colab
hf_token = userdata.get('HF_TOKEN')

# Esegui il login
if hf_token:
    login(token=hf_token)
    print("Login a Hugging Face riuscito!")
else:
    print("Secret HF_TOKEN non trovato. Assicurati di averlo aggiunto ai secret di Colab.")
# Out:
# Login a Hugging Face riuscito!

# %%
# %cd /content/drive/MyDrive/Stage-Buzzi/
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Stage-Buzzi
# ERROR: Operation cancelled by user

# %%
# %cd /content/drive/MyDrive/Stage-Buzzi/Classificazione/ViT/
#%rmdir /s training_results_temperatura
# !python train_model_pytorch.py temperatura
# Out:
# /content/drive/MyDrive/Stage-Buzzi/Classificazione/ViT
# 2025-10-25 10:27:21.999822: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-25 10:27:22.018883: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761388042.040707    3672 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python fix_validation_set.py
# Out:
# ...
# RIGENERAZIONE VALIDATION SET (senza training)
# ...
#
# Attributo: temperatura
# Caricamento dataset da HuggingFace...
# Resolving data files: 100% 1400/1400 [00:00<00:00, 3039.11it/s]
# Filtraggio dataset...
# Map: 100% 1400/1400 [00:00<00:00, 6966.00 examples/s]
# Filter: 100% 1400/1400 [00:39<00:00, 35.03 examples/s]
# Casting the dataset: 100% 1400/1400 [00:00<00:00, 64802.63 examples/s]
#
# Divisione dataset (80% Train, 20% Validation)...
# Train set: 1120 immagini
# Validation set: 280 immagini
#
# Salvataggio validation set...
# Saving the dataset (1/1 shards): 100% 280/280 [00:01<00:00, 181.50 examples/s]
#
# ...
# [OK] VALIDATION SET RIGENERATO!
# ...
# Salvato in: validation_test_set/
# Campioni: 280
#
# Il tuo modello addestrato e' ancora intatto.
#
# Ora puoi eseguire:
#   python evaluate_model_pytorch.py
# ...

# %%
#%cd drive/MyDrive/Stage-Buzzi/Classificazione/ViT/
# !python evaluate_model_pytorch.py
# Out:
# 2025-10-25 11:46:02.155764: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-25 11:46:02.174098: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761392762.196032   23482 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761392762.202553   23482 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#!pip install pydensecrf2
#%cd CNN/
# !python train_improved_classifier.py --cnn_model efficientnet_b0 --classifier xgboost --batch_size 1
# Out:
# python3: can't open file '/content/drive/MyDrive/Stage-Buzzi/Classificazione/ViT/train_improved_classifier.py': [Errno 2] No such file or directory

# %%
# %cd /content/Stage-Buzzi/CNN # Assicurati di essere nella directory corretta se requirements.txt è lì
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: '/content/Stage-Buzzi/CNN # Assicurati di essere nella directory corretta se requirements.txt è lì'
# /content/Segmentazione/CNN
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 9.1 MB/s eta 0:00:00
# ...

# %%
# !unzip Stage-Buzzi.zip
# Out:
# Output streaming troncato alle ultime 5000 righe.
#    creating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/
#   inflating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/configuration_megatron_bert.py
#   inflating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/modeling_megatron_bert.py
#   inflating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/__init__.py
#    creating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/__pycache__/
#   inflating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/__pycache__/configuration_megatron_bert.cpython-311.pyc
#   inflating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/__pycache__/modeling_megatron_bert.cpython-311.pyc
#   inflating: Stage-Buzzi/.venv/Lib/site-packages/transformers/models/megatron_bert/__pycache__/__init__.cpython-311.pyc
# ...
